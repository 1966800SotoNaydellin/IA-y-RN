# %% [markdown]
# <a href="https://colab.research.google.com/github/1966800SotoNaydellin/IA-y-RN/blob/main/Actividad_4_Soluci%C3%B3n_de_problemas_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Actividad fundamental #4: Árbol de decisión
Nombre:Naydellin Ivonne Soto Villegas
Matricula: 1966800
Hora:N1
"""

# %%
# Paso 1: Cargar librerías

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# %%
#Paso 2: Cargar datos

data = load_breast_cancer()
X = data.data
y = data.target

# %%
#Paso 3: Procesamiento de datos

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
#Paso 4: Selección y entrenamiento del modelo

model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#Paso 5: Prueba del modelo

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Exactitud del modelo:", accuracy)
# Out:
# Exactitud del modelo: 0.9438596491228071

# %%
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        98
#            1       0.97      0.95      0.96       187
#
#     accuracy                           0.94       285
#    macro avg       0.93      0.94      0.94       285
# weighted avg       0.94      0.94      0.94       285

# %%
plt.figure(figsize=(10, 8), dpi=300)
plot_tree(model, filled=True, feature_names=data.feature_names, class_names=data.target_names)
plt.show()
